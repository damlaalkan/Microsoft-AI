# %%
########### Python Form Recognizer Async Analyze #############
import json
import time
import getopt
import sys
import os
from requests import get, post

# %%
def runAnalysis(input_file, output_file):
    # Endpoint URL
    endpoint = r"<endpoint url>"
    # Subscription Key
    apim_key = "<fr key>"
    # Model ID
    model_id = "<id>"
    post_url = endpoint + "/formrecognizer/v2.0/custom/models/%s/analyze" % model_id
    params = {
        "includeTextDetails": True
    }

    headers = {
        # Request headers
        'Content-Type': 'image/jpeg',
        'Ocp-Apim-Subscription-Key': apim_key,
    }
    try:
        with open(input_file, "rb") as f:
            data_bytes = f.read()
    except IOError:
        print("Inputfile not accessible.")
        sys.exit(2)

    try:
        print('Initiating analysis...')
        resp = post(url = post_url, data = data_bytes, headers = headers, params = params)
        if resp.status_code != 202:
            print("POST analyze failed:\n%s" % json.dumps(resp.json()))
            quit()
        print("POST analyze succeeded:\n%s" % resp.headers)
        print
        get_url = resp.headers["operation-location"]
    except Exception as e:
        print("POST analyze failed:\n%s" % str(e))
        quit()

    n_tries = 15
    n_try = 0
    wait_sec = 5
    max_wait_sec = 60
    print()
    print('Getting analysis results...')
    while n_try < n_tries:
        try:
            resp = get(url = get_url, headers = {"Ocp-Apim-Subscription-Key": apim_key})
            resp_json = resp.json()
            if resp.status_code != 200:
                print("GET analyze results failed:\n%s" % json.dumps(resp_json))
                quit()
            status = resp_json["status"]
            if status == "succeeded":
                if output_file:
                    with open(output_file, 'w') as outfile:
                        json.dump(resp_json, outfile, indent=2, sort_keys=True)
                print("Analysis succeeded:\n%s" % json.dumps(resp_json, indent=2, sort_keys=True))
                quit()
            if status == "failed":
                print("Analysis failed:\n%s" % json.dumps(resp_json))
                quit()
            # Analysis still running. Wait and retry.
            time.sleep(wait_sec)
            n_try += 1
            wait_sec = min(2*wait_sec, max_wait_sec)     
        except Exception as e:
            msg = "GET analyze results failed:\n%s" % str(e)
            print(msg)
            quit()
    print("Analyze operation did not complete within the allocated time.")

# %%
input_file = 'test1.jpeg'
output_file = 'fr.txt'

runAnalysis(input_file, output_file)
# Out:
# Initiating analysis...
# POST analyze succeeded:
# {'Content-Length': '0', 'Operation-Location': 'https://formrecognizerhuma.cognitiveservices.azure.com/formrecognizer/v2.0/custom/models/60e050fd-27b0-4c20-a7dd-0fd2cc3710d9/analyzeresults/c4c15434-4281-4729-8d2e-16efd3db5e01', 'x-envoy-upstream-service-time': '82', 'apim-request-id': '6cef0e1a-d8c4-4628-b504-d9a12f4ce03e', 'Strict-Transport-Security': 'max-age=31536000; includeSubDomains; preload', 'x-content-type-options': 'nosniff', 'Date': 'Tue, 23 Feb 2021 12:26:33 GMT'}
#
# Getting analysis results...
# Analysis succeeded:
# {
#   "analyzeResult": {
#     "documentResults": [
#       {
#         "docType": "custom:form",
#         "fields": {
#           "ad_soyad": {
#             "boundingBox": [
#               445.0,
#               203.0,
#               501.0,
#               203.0,
#               501.0,
#               215.0,
#               445.0,
#               215.0
#             ],
#             "confidence": 0.926,
#             "elements": [
#               "#/readResults/0/lines/12/words/0",
#               "#/readResults/0/lines/12/words/1"
#             ],
#             "page": 1,
#             "text": "Sinem Kiaid",
#             "type": "string",
#             "valueString": "Sinem Kiaid"
#           },
#           "anapara": {
#             "boundingBox": [
#               460.0,
#               311.0,
#               488.0,
#               311.0,
#               488.0,
#               322.0,
#               460.0,
#               322.0
#             ],
#             "confidence": 0.98,
#             "elements": [
#               "#/readResults/0/lines/21/words/0"
#             ],
#             "page": 1,
#             "text": "12612",
#             "type": "string",
#             "valueString": "12612"
#           },
#           "ayrilma_brut": {
#             "boundingBox": [
#               512.0,
#               595.0,
#               547.0,
#               595.0,
#               547.0,
#               605.0,
#               512.0,
#               605.0
#             ],
#             "confidence": 0.99,
#             "elements": [
#               "#/readResults/0/lines/57/words/0"
#             ],
#             "page": 1,
#             "text": "362534",
#             "type": "string",
#             "valueString": "362534"
#           },
#           "bireysel_em_hes_no": {
#             "boundingBox": [
#               459.0,
#               152.0,
#               485.0,
#               152.0,
#               485.0,
#               163.0,
#               459.0,
#               163.0
#             ],
#             "confidence": 0.721,
#             "elements": [
#               "#/readResults/0/lines/6/words/0"
#             ],
#             "page": 1,
#             "text": "84624",
#             "type": "string",
#             "valueString": "84624"
#           },
#           "birikim_devlet_toplam": {
#             "boundingBox": [
#               459.0,
#               278.0,
#               487.0,
#               278.0,
#               487.0,
#               293.0,
#               459.0,
#               293.0
#             ],
#             "confidence": 0.997,
#             "elements": [
#               "#/readResults/0/lines/18/words/7"
#             ],
#             "page": 1,
#             "text": "41254",
#             "type": "string",
#             "valueString": "41254"
#           },
#           "dk_kazanilmamis_toplam": {
#             "boundingBox": [
#               462.0,
#               415.0,
#               482.0,
#               415.0,
#               482.0,
#               425.0,
#               462.0,
#               425.0
#             ],
#             "confidence": 0.877,
#             "elements": [
#               "#/readResults/0/lines/33/words/0"
#             ],
#             "page": 1,
#             "text": "4564",
#             "type": "string",
#             "valueString": "4564"
#           },
#           "dk_kazanilmis_toplam": {
#             "boundingBox": [
#               460.0,
#               396.0,
#               486.0,
#               396.0,
#               486.0,
#               407.0,
#               460.0,
#               407.0
#             ],
#             "confidence": 1.0,
#             "elements": [
#               "#/readResults/0/lines/31/words/0"
#             ],
#             "page": 1,
#             "text": "45646",
#             "type": "string",
#             "valueString": "45646"
#           },
#           "grup_ana_soz_no": {
#             "boundingBox": [
#               443.0,
#               171.0,
#               499.0,
#               171.0,
#               499.0,
#               182.0,
#               443.0,
#               182.0
#             ],
#             "confidence": 0.81,
#             "elements": [
#               "#/readResults/0/lines/8/words/0"
#             ],
#             "page": 1,
#             "text": "5462938659",
#             "type": "string",
#             "valueString": "5462938659"
#           },
#           "hesap_oz_tanzim_tarih": {
#             "boundingBox": [
#               443.0,
#               187.0,
#               496.0,
#               187.0,
#               496.0,
#               199.0,
#               443.0,
#               199.0
#             ],
#             "confidence": 0.49,
#             "elements": [
#               "#/readResults/0/lines/10/words/0"
#             ],
#             "page": 1,
#             "text": ":12.30.2009",
#             "type": "string",
#             "valueString": ":12.30.2009"
#           },
#           "sozlesme_yurur_tarih": {
#             "boundingBox": [
#               443.0,
#               235.0,
#               497.0,
#               235.0,
#               497.0,
#               248.0,
#               443.0,
#               248.0
#             ],
#             "confidence": 0.57,
#             "elements": [
#               "#/readResults/0/lines/16/words/0"
#             ],
#             "page": 1,
#             "text": ":12.12.2009",
#             "type": "string",
#             "valueString": ":12.12.2009"
#           },
#           "tc_no": {
#             "boundingBox": [
#               450.0,
#               219.0,
#               510.0,
#               219.0,
#               510.0,
#               230.0,
#               450.0,
#               230.0
#             ],
#             "confidence": 0.87,
#             "elements": [
#               "#/readResults/0/lines/14/words/0"
#             ],
#             "page": 1,
#             "text": "13211100098",
#             "type": "string",
#             "valueString": "13211100098"
#           },
#           "yatirim_getirisi": {
#             "boundingBox": [
#               465.0,
#               327.0,
#               480.0,
#               327.0,
#               480.0,
#               337.0,
#               465.0,
#               337.0
#             ],
#             "confidence": 0.988,
#             "elements": [
#               "#/readResults/0/lines/23/words/0"
#             ],
#             "page": 1,
#             "text": "474",
#             "type": "string",
#             "valueString": "474"
#           }
#         },
#         "pageRange": [
#           1,
#           1
#         ]
#       }
#     ],
#     "errors": [],
#     "pageResults": [
#       {
#         "page": 1,
#         "tables": [
#           {
#             "cells": [
#               {
#                 "boundingBox": [
#                   67,
#                   311,
#                   591,
#                   311,
#                   591,
#                   450,
#                   67,
#                   450
#                 ],
#                 "columnIndex": 0,
#                 "columnSpan": 2,
#                 "elements": [
#                   "#/readResults/0/lines/20/words/0",
#                   "#/readResults/0/lines/20/words/1",
#                   "#/readResults/0/lines/21/words/0",
#                   "#/readResults/0/lines/22/words/0",
#                   "#/readResults/0/lines/22/words/1",
#                   "#/readResults/0/lines/22/words/2",
#                   "#/readResults/0/lines/23/words/0",
#                   "#/readResults/0/lines/24/words/0",
#                   "#/readResults/0/lines/24/words/1",
#                   "#/readResults/0/lines/24/words/2",
#                   "#/readResults/0/lines/24/words/3",
#                   "#/readResults/0/lines/24/words/4",
#                   "#/readResults/0/lines/24/words/5",
#                   "#/readResults/0/lines/24/words/6",
#                   "#/readResults/0/lines/24/words/7",
#                   "#/readResults/0/lines/25/words/0",
#                   "#/readResults/0/lines/26/words/0",
#                   "#/readResults/0/lines/26/words/1",
#                   "#/readResults/0/lines/26/words/2",
#                   "#/readResults/0/lines/26/words/3",
#                   "#/readResults/0/lines/26/words/4",
#                   "#/readResults/0/lines/26/words/5",
#                   "#/readResults/0/lines/26/words/6",
#                   "#/readResults/0/lines/26/words/7",
#                   "#/readResults/0/lines/27/words/0",
#                   "#/readResults/0/lines/28/words/0",
#                   "#/readResults/0/lines/28/words/1",
#                   "#/readResults/0/lines/28/words/2",
#                   "#/readResults/0/lines/28/words/3",
#                   "#/readResults/0/lines/28/words/4",
#                   "#/readResults/0/lines/28/words/5",
#                   "#/readResults/0/lines/28/words/6",
#                   "#/readResults/0/lines/28/words/7",
#                   "#/readResults/0/lines/29/words/0",
#                   "#/readResults/0/lines/30/words/0",
#                   "#/readResults/0/lines/30/words/1",
#                   "#/readResults/0/lines/30/words/2",
#                   "#/readResults/0/lines/30/words/3",
#                   "#/readResults/0/lines/30/words/4",
#                   "#/readResults/0/lines/30/words/5",
#                   "#/readResults/0/lines/30/words/6",
#                   "#/readResults/0/lines/30/words/7",
#                   "#/readResults/0/lines/31/words/0",
#                   "#/readResults/0/lines/32/words/0",
#                   "#/readResults/0/lines/32/words/1",
#                   "#/readResults/0/lines/32/words/2",
#                   "#/readResults/0/lines/32/words/3",
#                   "#/readResults/0/lines/32/words/4",
#                   "#/readResults/0/lines/32/words/5",
#                   "#/readResults/0/lines/32/words/6",
#                   "#/readResults/0/lines/33/words/0",
#                   "#/readResults/0/lines/34/words/0",
#                   "#/readResults/0/lines/34/words/1",
#                   "#/readResults/0/lines/34/words/2",
#                   "#/readResults/0/lines/34/words/3",
#                   "#/readResults/0/lines/34/words/4"
#                 ],
#                 "rowIndex": 0,
#                 "text": ". Anapara 12612 . Yatinm Getirisi 474 DK Hesabindaki Tutar / DK Hak Kazanma Orani 8080 . DK Anaparasi / Hak Kazanilmis DK Anaparasi 8000 . DK Getirisi / Hak Kazanilmis DK Getirisi 4643 . DK Hesabindaki Hak Kazanilmis Toplam Tutar : 45646 . DK Hesabindaki Hak Kazanilmamis Toplam Tutar: 4564 Birikimi Olusturan Emeklilik Yatinm Fonlan"
#               },
#               {
#                 "boundingBox": [
#                   67,
#                   450,
#                   486,
#                   450,
#                   486,
#                   474,
#                   67,
#                   474
#                 ],
#                 "columnIndex": 0,
#                 "elements": [
#                   "#/readResults/0/lines/35/words/0",
#                   "#/readResults/0/lines/35/words/1",
#                   "#/readResults/0/lines/36/words/0",
#                   "#/readResults/0/lines/36/words/1"
#                 ],
#                 "rowIndex": 1,
#                 "text": "Fon Adi Pay Adedi"
#               },
#               {
#                 "boundingBox": [
#                   486,
#                   450,
#                   591,
#                   450,
#                   591,
#                   474,
#                   486,
#                   474
#                 ],
#                 "columnIndex": 1,
#                 "elements": [
#                   "#/readResults/0/lines/37/words/0",
#                   "#/readResults/0/lines/37/words/1"
#                 ],
#                 "rowIndex": 1,
#                 "text": "Pay Fiyati"
#               },
#               {
#                 "boundingBox": [
#                   591,
#                   450,
#                   665,
#                   450,
#                   665,
#                   474,
#                   591,
#                   474
#                 ],
#                 "columnIndex": 2,
#                 "elements": [
#                   "#/readResults/0/lines/38/words/0",
#                   "#/readResults/0/lines/38/words/1"
#                 ],
#                 "rowIndex": 1,
#                 "text": "Fon Degeri"
#               },
#               {
#                 "boundingBox": [
#                   67,
#                   474,
#                   486,
#                   474,
#                   486,
#                   498,
#                   67,
#                   498
#                 ],
#                 "columnIndex": 0,
#                 "elements": [
#                   "#/readResults/0/lines/39/words/0",
#                   "#/readResults/0/lines/39/words/1",
#                   "#/readResults/0/lines/39/words/2",
#                   "#/readResults/0/lines/39/words/3",
#                   "#/readResults/0/lines/39/words/4",
#                   "#/readResults/0/lines/39/words/5",
#                   "#/readResults/0/lines/40/words/0"
#                 ],
#                 "rowIndex": 2,
#                 "text": "(Devlet Katkisi Fonu) AHE Kathi Fonu 3273"
#               },
#               {
#                 "boundingBox": [
#                   486,
#                   474,
#                   591,
#                   474,
#                   591,
#                   498,
#                   486,
#                   498
#                 ],
#                 "columnIndex": 1,
#                 "elements": [
#                   "#/readResults/0/lines/41/words/0"
#                 ],
#                 "rowIndex": 2,
#                 "text": "4865"
#               },
#               {
#                 "boundingBox": [
#                   591,
#                   474,
#                   665,
#                   474,
#                   665,
#                   498,
#                   591,
#                   498
#                 ],
#                 "columnIndex": 2,
#                 "elements": [
#                   "#/readResults/0/lines/42/words/0"
#                 ],
#                 "rowIndex": 2,
#                 "text": "2739"
#               },
#               {
#                 "boundingBox": [
#                   67,
#                   498,
#                   486,
#                   498,
#                   486,
#                   519,
#                   67,
#                   519
#                 ],
#                 "columnIndex": 0,
#                 "elements": [
#                   "#/readResults/0/lines/43/words/0",
#                   "#/readResults/0/lines/43/words/1",
#                   "#/readResults/0/lines/43/words/2",
#                   "#/readResults/0/lines/43/words/3",
#                   "#/readResults/0/lines/44/words/0"
#                 ],
#                 "rowIndex": 3,
#                 "text": "AHE Para Piyasasi Fonu 2344"
#               },
#               {
#                 "boundingBox": [
#                   486,
#                   498,
#                   591,
#                   498,
#                   591,
#                   519,
#                   486,
#                   519
#                 ],
#                 "columnIndex": 1,
#                 "elements": [
#                   "#/readResults/0/lines/45/words/0"
#                 ],
#                 "rowIndex": 3,
#                 "text": "4234"
#               },
#               {
#                 "boundingBox": [
#                   591,
#                   498,
#                   665,
#                   498,
#                   665,
#                   519,
#                   591,
#                   519
#                 ],
#                 "columnIndex": 2,
#                 "elements": [
#                   "#/readResults/0/lines/46/words/0"
#                 ],
#                 "rowIndex": 3,
#                 "text": "24314"
#               },
#               {
#                 "boundingBox": [
#                   67,
#                   519,
#                   486,
#                   519,
#                   486,
#                   541,
#                   67,
#                   541
#                 ],
#                 "columnIndex": 0,
#                 "elements": [
#                   "#/readResults/0/lines/47/words/0",
#                   "#/readResults/0/lines/47/words/1",
#                   "#/readResults/0/lines/47/words/2",
#                   "#/readResults/0/lines/47/words/3",
#                   "#/readResults/0/lines/47/words/4",
#                   "#/readResults/0/lines/48/words/0"
#                 ],
#                 "rowIndex": 4,
#                 "text": "AHE Birinci Kamu Dis Borclanma 23412"
#               },
#               {
#                 "boundingBox": [
#                   486,
#                   519,
#                   591,
#                   519,
#                   591,
#                   541,
#                   486,
#                   541
#                 ],
#                 "columnIndex": 1,
#                 "elements": [
#                   "#/readResults/0/lines/49/words/0"
#                 ],
#                 "rowIndex": 4,
#                 "text": "2431"
#               },
#               {
#                 "boundingBox": [
#                   591,
#                   519,
#                   665,
#                   519,
#                   665,
#                   541,
#                   591,
#                   541
#                 ],
#                 "columnIndex": 2,
#                 "elements": [
#                   "#/readResults/0/lines/50/words/0"
#                 ],
#                 "rowIndex": 4,
#                 "text": "234431"
#               },
#               {
#                 "boundingBox": [
#                   67,
#                   541,
#                   486,
#                   541,
#                   486,
#                   586,
#                   67,
#                   586
#                 ],
#                 "columnIndex": 0,
#                 "elements": [
#                   "#/readResults/0/lines/51/words/0",
#                   "#/readResults/0/lines/51/words/1",
#                   "#/readResults/0/lines/51/words/2",
#                   "#/readResults/0/lines/51/words/3",
#                   "#/readResults/0/lines/51/words/4",
#                   "#/readResults/0/lines/52/words/0",
#                   "#/readResults/0/lines/55/words/0",
#                   "#/readResults/0/lines/55/words/1"
#                 ],
#                 "rowIndex": 5,
#                 "text": "AHE Gelismis Ulkeler Degisken Fon 234 Aynlma Tutarlan"
#               },
#               {
#                 "boundingBox": [
#                   486,
#                   541,
#                   591,
#                   541,
#                   591,
#                   586,
#                   486,
#                   586
#                 ],
#                 "columnIndex": 1,
#                 "elements": [
#                   "#/readResults/0/lines/53/words/0"
#                 ],
#                 "rowIndex": 5,
#                 "text": "4231"
#               },
#               {
#                 "boundingBox": [
#                   591,
#                   541,
#                   665,
#                   541,
#                   665,
#                   586,
#                   591,
#                   586
#                 ],
#                 "columnIndex": 2,
#                 "elements": [
#                   "#/readResults/0/lines/54/words/0"
#                 ],
#                 "rowIndex": 5,
#                 "text": "43645"
#               },
#               {
#                 "boundingBox": [
#                   67,
#                   586,
#                   486,
#                   586,
#                   486,
#                   622,
#                   67,
#                   622
#                 ],
#                 "columnIndex": 0,
#                 "elements": [
#                   "#/readResults/0/lines/56/words/0",
#                   "#/readResults/0/lines/56/words/1",
#                   "#/readResults/0/lines/56/words/2",
#                   "#/readResults/0/lines/56/words/3",
#                   "#/readResults/0/lines/58/words/0",
#                   "#/readResults/0/lines/58/words/1",
#                   "#/readResults/0/lines/58/words/2",
#                   "#/readResults/0/lines/58/words/3",
#                   "#/readResults/0/lines/58/words/4",
#                   "#/readResults/0/lines/58/words/5",
#                   "#/readResults/0/lines/58/words/6"
#                 ],
#                 "rowIndex": 6,
#                 "text": "AYRILMAYA ESAS BRUT BIRIKIM (Devlet Katkisi Hesabindaki Hak Kazanilmis Tutar dahil)"
#               },
#               {
#                 "boundingBox": [
#                   486,
#                   586,
#                   591,
#                   586,
#                   591,
#                   622,
#                   486,
#                   622
#                 ],
#                 "columnIndex": 1,
#                 "elements": [
#                   "#/readResults/0/lines/57/words/0"
#                 ],
#                 "rowIndex": 6,
#                 "text": "362534"
#               },
#               {
#                 "boundingBox": [
#                   67,
#                   622,
#                   486,
#                   622,
#                   486,
#                   638,
#                   67,
#                   638
#                 ],
#                 "columnIndex": 0,
#                 "elements": [
#                   "#/readResults/0/lines/59/words/0",
#                   "#/readResults/0/lines/59/words/1",
#                   "#/readResults/0/lines/59/words/2"
#                 ],
#                 "rowIndex": 7,
#                 "text": "Giris Aidati Kesintisi"
#               },
#               {
#                 "boundingBox": [
#                   486,
#                   622,
#                   591,
#                   622,
#                   591,
#                   638,
#                   486,
#                   638
#                 ],
#                 "columnIndex": 1,
#                 "elements": [
#                   "#/readResults/0/lines/60/words/0"
#                 ],
#                 "rowIndex": 7,
#                 "text": "91219"
#               },
#               {
#                 "boundingBox": [
#                   67,
#                   638,
#                   486,
#                   638,
#                   486,
#                   674,
#                   67,
#                   674
#                 ],
#                 "columnIndex": 0,
#                 "elements": [
#                   "#/readResults/0/lines/61/words/0",
#                   "#/readResults/0/lines/61/words/1",
#                   "#/readResults/0/lines/61/words/2",
#                   "#/readResults/0/lines/61/words/3",
#                   "#/readResults/0/lines/61/words/4",
#                   "#/readResults/0/lines/61/words/5",
#                   "#/readResults/0/lines/61/words/6",
#                   "#/readResults/0/lines/63/words/0"
#                 ],
#                 "rowIndex": 8,
#                 "text": "Aynlma Durumunda Uygulanacak Gelir Vergisi Oram / Tutan"
#               },
#               {
#                 "boundingBox": [
#                   486,
#                   638,
#                   591,
#                   638,
#                   591,
#                   674,
#                   486,
#                   674
#                 ],
#                 "columnIndex": 1,
#                 "elements": [
#                   "#/readResults/0/lines/62/words/0"
#                 ],
#                 "rowIndex": 8,
#                 "text": "362534"
#               },
#               {
#                 "boundingBox": [
#                   67,
#                   674,
#                   486,
#                   674,
#                   486,
#                   691,
#                   67,
#                   691
#                 ],
#                 "columnIndex": 0,
#                 "elements": [
#                   "#/readResults/0/lines/64/words/0",
#                   "#/readResults/0/lines/64/words/1",
#                   "#/readResults/0/lines/64/words/2",
#                   "#/readResults/0/lines/64/words/3"
#                 ],
#                 "rowIndex": 9,
#                 "text": "AYRILMAYA ESAS NET BIRIKIM"
#               },
#               {
#                 "boundingBox": [
#                   486,
#                   674,
#                   591,
#                   674,
#                   591,
#                   691,
#                   486,
#                   691
#                 ],
#                 "columnIndex": 1,
#                 "elements": [
#                   "#/readResults/0/lines/65/words/0"
#                 ],
#                 "rowIndex": 9,
#                 "text": "362534"
#               }
#             ],
#             "columns": 3,
#             "rows": 10
#           }
#         ]
#       }
#     ],
#     "readResults": [
#       {
#         "angle": 0,
#         "height": 1024,
#         "language": "en",
#         "lines": [
#           {
#             "boundingBox": [
#               498,
#               37,
#               693,
#               42,
#               692,
#               56,
#               498,
#               54
#             ],
#             "text": "Herkese ly Calecek ANADOLU HAYAT",
#             "words": [
#               {
#                 "boundingBox": [
#                   499,
#                   38,
#                   533,
#                   39,
#                   534,
#                   55,
#                   500,
#                   54
#                 ],
#                 "confidence": 0.762,
#                 "text": "Herkese"
#               },
#               {
#                 "boundingBox": [
#                   537,
#                   39,
#                   550,
#                   39,
#                   550,
#                   55,
#                   537,
#                   55
#                 ],
#                 "confidence": 0.441,
#                 "text": "ly"
#               },
#               {
#                 "boundingBox": [
#                   553,
#                   40,
#                   591,
#                   41,
#                   591,
#                   55,
#                   554,
#                   55
#                 ],
#                 "confidence": 0.43,
#                 "text": "Calecek"
#               },
#               {
#                 "boundingBox": [
#                   607,
#                   42,
#                   657,
#                   44,
#                   657,
#                   56,
#                   607,
#                   55
#                 ],
#                 "confidence": 0.328,
#                 "text": "ANADOLU"
#               },
#               {
#                 "boundingBox": [
#                   660,
#                   44,
#                   693,
#                   45,
#                   693,
#                   56,
#                   660,
#                   56
#                 ],
#                 "confidence": 0.487,
#                 "text": "HAYAT"
#               }
#             ]
#           },
#           {
#             "boundingBox": [
#               619,
#               56,
#               676,
#               55,
#               676,
#               66,
#               619,
#               67
#             ],
#             "text": "EMEKLILIK",
#             "words": [
#               {
#                 "boundingBox": [
#                   621,
#                   56,
#                   676,
#                   55,
#                   676,
#                   67,
#                   621,
#                   68
#                 ],
#                 "confidence": 0.465,
#                 "text": "EMEKLILIK"
#               }
#             ]
#           },
#           {
#             "boundingBox": [
#               76,
#               76,
#               270,
#               75,
#               270,
#               93,
#               76,
#               93
#             ],
#             "text": "KATILIMCI HESAP OZETI",
#             "words": [
#               {
#                 "boundingBox": [
#                   78,
#                   78,
#                   163,
#                   76,
#                   162,
#                   93,
#                   78,
#                   92
#                 ],
#                 "confidence": 0.909,
#                 "text": "KATILIMCI"
#               },
#               {
#                 "boundingBox": [
#                   166,
#                   76,
#                   218,
#                   76,
#                   217,
#                   93,
#                   165,
#                   93
#                 ],
#                 "confidence": 0.959,
#                 "text": "HESAP"
#               },
#               {
#                 "boundingBox": [
#                   223,
#                   76,
#                   271,
#                   76,
#                   270,
#                   93,
#                   222,
#                   93
#                 ],
#                 "confidence": 0.184,
#                 "text": "OZETI"
#               }
#             ]
#           },
#           {
#             "boundingBox": [
#               483,
#               79,
#               636,
#               79,
#               636,
#               93,
#               483,
#               93
#             ],
#             "text": "Lutfen arka sayfay ceviriniz.",
#             "words": [
#               {
#                 "boundingBox": [
#                   485,
#                   79,
#                   519,
#                   80,
#                   519,
#                   93,
#                   484,
#                   93
#                 ],
#                 "confidence": 0.954,
#                 "text": "Lutfen"
#               },
#               {
#                 "boundingBox": [
#                   522,
#                   80,
#                   545,
#                   80,
#                   545,
#                   93,
#                   521,
#                   93
#                 ],
#                 "confidence": 0.946,
#                 "text": "arka"
#               },
#               {
#                 "boundingBox": [
#                   548,
#                   80,
#                   584,
#                   80,
#                   584,
#                   93,
#                   547,
#                   93
#                 ],
#                 "confidence": 0.799,
#                 "text": "sayfay"
#               },
#               {
#                 "boundingBox": [
#                   588,
#                   80,
#                   637,
#                   79,
#                   637,
#                   94,
#                   587,
#                   93
#                 ],
#                 "confidence": 0.938,
#                 "text": "ceviriniz."
#               }
#             ]
#           },
#           {
#             "boundingBox": [
#               83,
#               123,
#               246,
#               120,
#               246,
#               137,
#               83,
#               139
#             ],
#             "text": "REFERANS BILGILERI",
#             "words": [
#               {
#                 "boundingBox": [
#                   84,
#                   125,
#                   165,
#                   123,
#                   165,
#                   138,
#                   85,
#                   138
#                 ],
#                 "confidence": 0.959,
#                 "text": "REFERANS"
#               },
#               {
#                 "boundingBox": [
#                   169,
#                   123,
#                   246,
#                   121,
#                   245,
#                   137,
#                   169,
#                   138
#                 ],
#                 "confidence": 0.609,
#                 "text": "BILGILERI"
#               }
#             ]
#           },
#           {
#             "boundingBox": [
#               86,
#               152,
#               318,
#               151,
#               318,
#               168,
#               86,
#               168
#             ],
#             "text": "Bireysel Emeklilik Hesap Numarasi",
#             "words": [
#               {
#                 "boundingBox": [
#                   87,
#                   153,
#                   140,
#                   153,
#                   139,
#                   168,
#                   87,
#                   168
#                 ],
#                 "confidence": 0.959,
#                 "text": "Bireysel"
#               },
#               {
#                 "boundingBox": [
#                   143,
#                   153,
#                   204,
#                   152,
#                   204,
#                   169,
#                   142,
#                   168
#                 ],
#                 "confidence": 0.944,
#                 "text": "Emeklilik"
#               },
#               {
#                 "boundingBox": [
#                   207,
#                   152,
#                   249,
#                   152,
#                   249,
#                   168,
#                   207,
#                   169
#                 ],
#                 "confidence": 0.959,
#                 "text": "Hesap"
#               },
#               {
#                 "boundingBox": [
#                   252,
#                   152,
#                   318,
#                   152,
#                   318,
#                   168,
#                   252,
#                   168
#                 ],
#                 "confidence": 0.62,
#                 "text": "Numarasi"
#               }
#             ]
#           },
#           {
#             "boundingBox": [
#               459,
#               153,
#               486,
#               152,
#               486,
#               163,
#               459,
#               163
#             ],
#             "text": "84624",
#             "words": [
#               {
#                 "boundingBox": [
#                   459,
#                   152,
#                   485,
#                   152,
#                   485,
#                   163,
#                   459,
#                   163
#                 ],
#                 "confidence": 0.423,
#                 "text": "84624"
#               }
#             ]
#           },
#           {
#             "boundingBox": [
#               86,
#               168,
#               288,
#               168,
#               288,
#               184,
#               86,
#               184
#             ],
#             "text": "Grup Ana Sozlesme Numarasi",
#             "words": [
#               {
#                 "boundingBox": [
#                   88,
#                   169,
#                   121,
#                   168,
#                   121,
#                   184,
#                   88,
#                   184
#                 ],
#                 "confidence": 0.959,
#                 "text": "Grup"
#               },
#               {
#                 "boundingBox": [
#                   124,
#                   168,
#                   151,
#                   168,
#                   151,
#                   185,
#                   124,
#                   184
#                 ],
#                 "confidence": 0.951,
#                 "text": "Ana"
#               },
#               {
#                 "boundingBox": [
#                   154,
#                   168,
#                   217,
#                   168,
#                   217,
#                   185,
#                   154,
#                   185
#                 ],
#                 "confidence": 0.958,
#                 "text": "Sozlesme"
#               },
#               {
#                 "boundingBox": [
#                   220,
#                   168,
#                   288,
#                   169,
#                   288,
#                   184,
#                   220,
#                   185
#                 ],
#                 "confidence": 0.589,
#                 "text": "Numarasi"
#               }
#             ]
#           },
#           {
#             "boundingBox": [
#               443,
#               171,
#               499,
#               171,
#               499,
#               182,
#               443,
#               181
#             ],
#             "text": "5462938659",
#             "words": [
#               {
#                 "boundingBox": [
#                   443,
#                   171,
#                   499,
#                   172,
#                   499,
#                   182,
#                   443,
#                   181
#                 ],
#                 "confidence": 0.442,
#                 "text": "5462938659"
#               }
#             ]
#           },
#           {
#             "boundingBox": [
#               85,
#               184,
#               421,
#               183,
#               421,
#               198,
#               85,
#               200
#             ],
#             "text": "Hesap Ozeti Referans No. / Tanzim Tarihi / Nedeni",
#             "words": [
#               {
#                 "boundingBox": [
#                   87,
#                   185,
#                   128,
#                   185,
#                   128,
#                   200,
#                   86,
#                   200
#                 ],
#                 "confidence": 0.959,
#                 "text": "Hesap"
#               },
#               {
#                 "boundingBox": [
#                   131,
#                   185,
#                   167,
#                   184,
#                   167,
#                   200,
#                   131,
#                   200
#                 ],
#                 "confidence": 0.945,
#                 "text": "Ozeti"
#               },
#               {
#                 "boundingBox": [
#                   169,
#                   184,
#                   228,
#                   184,
#                   228,
#                   200,
#                   169,
#                   200
#                 ],
#                 "confidence": 0.959,
#                 "text": "Referans"
#               },
#               {
#                 "boundingBox": [
#                   231,
#                   184,
#                   253,
#                   184,
#                   253,
#                   200,
#                   231,
#                   200
#                 ],
#                 "confidence": 0.957,
#                 "text": "No."
#               },
#               {
#                 "boundingBox": [
#                   256,
#                   184,
#                   264,
#                   184,
#                   264,
#                   200,
#                   256,
#                   200
#                 ],
#                 "confidence": 0.896,
#                 "text": "/"
#               },
#               {
#                 "boundingBox": [
#                   267,
#                   183,
#                   313,
#                   183,
#                   313,
#                   199,
#                   267,
#                   200
#                 ],
#                 "confidence": 0.959,
#                 "text": "Tanzim"
#               },
#               {
#                 "boundingBox": [
#                   321,
#                   183,
#                   359,
#                   183,
#                   359,
#                   199,
#                   321,
#                   199
#                 ],
#                 "confidence": 0.848,
#                 "text": "Tarihi"
#               },
#               {
#                 "boundingBox": [
#                   362,
#                   183,
#                   369,
#                   183,
#                   369,
#                   199,
#                   362,
#                   199
#                 ],
#                 "confidence": 0.895,
#                 "text": "/"
#               },
#               {
#                 "boundingBox": [
#                   372,
#                   183,
#                   421,
#                   183,
#                   421,
#                   198,
#                   372,
#                   199
#                 ],
#                 "confidence": 0.958,
#                 "text": "Nedeni"
#               }
#             ]
#           },
#           {
#             "boundingBox": [
#               443,
#               186,
#               496,
#               187,
#               496,
#               198,
#               443,
#               197
#             ],
#             "text": ":12.30.2009",
#             "words": [
#               {
#                 "boundingBox": [
#                   443,
#                   187,
#                   496,
#                   188,
#                   496,
#                   199,
#                   443,
#                   198
#                 ],
#                 "confidence": 0.639,
#                 "text": ":12.30.2009"
#               }
#             ]
#           },
#           {
#             "boundingBox": [
#               86,
#               199,
#               242,
#               199,
#               242,
#               214,
#               86,
#               215
#             ],
#             "text": "Katilimci Adi ve Soyadi",
#             "words": [
#               {
#                 "boundingBox": [
#                   87,
#                   200,
#                   148,
#                   200,
#                   148,
#                   215,
#                   87,
#                   214
#                 ],
#                 "confidence": 0.411,
#                 "text": "Katilimci"
#               },
#               {
#                 "boundingBox": [
#                   151,
#                   200,
#                   174,
#                   200,
#                   174,
#                   215,
#                   151,
#                   215
#                 ],
#                 "confidence": 0.878,
#                 "text": "Adi"
#               },
#               {
#                 "boundingBox": [
#                   176,
#                   200,
#                   193,
#                   200,
#                   193,
#                   215,
#                   176,
#                   215
#                 ],
#                 "confidence": 0.958,
#                 "text": "ve"
#               },
#               {
#                 "boundingBox": [
#                   195,
#                   200,
#                   243,
#                   199,
#                   243,
#                   215,
#                   195,
#                   215
#                 ],
#                 "confidence": 0.799,
#                 "text": "Soyadi"
#               }
#             ]
#           },
#           {
#             "boundingBox": [
#               444,
#               203,
#               501,
#               203,
#               501,
#               214,
#               444,
#               214
#             ],
#             "text": "Sinem Kiaid",
#             "words": [
#               {
#                 "boundingBox": [
#                   445,
#                   203,
#                   472,
#                   204,
#                   472,
#                   215,
#                   446,
#                   214
#                 ],
#                 "confidence": 0.955,
#                 "text": "Sinem"
#               },
#               {
#                 "boundingBox": [
#                   475,
#                   204,
#                   501,
#                   203,
#                   501,
#                   215,
#                   475,
#                   215
#                 ],
#                 "confidence": 0.284,
#                 "text": "Kiaid"
#               }
#             ]
#           },
#           {
#             "boundingBox": [
#               85,
#               215,
#               294,
#               215,
#               294,
#               230,
#               85,
#               231
#             ],
#             "text": "Katilime T.C. Kimlik Numarasi",
#             "words": [
#               {
#                 "boundingBox": [
#                   87,
#                   216,
#                   145,
#                   215,
#                   145,
#                   231,
#                   87,
#                   232
#                 ],
#                 "confidence": 0.309,
#                 "text": "Katilime"
#               },
#               {
#                 "boundingBox": [
#                   151,
#                   215,
#                   175,
#                   215,
#                   175,
#                   231,
#                   151,
#                   231
#                 ],
#                 "confidence": 0.958,
#                 "text": "T.C."
#               },
#               {
#                 "boundingBox": [
#                   178,
#                   215,
#                   223,
#                   215,
#                   223,
#                   230,
#                   178,
#                   231
#                 ],
#                 "confidence": 0.958,
#                 "text": "Kimlik"
#               },
#               {
#                 "boundingBox": [
#                   226,
#                   215,
#                   294,
#                   216,
#                   293,
#                   230,
#                   226,
#                   230
#                 ],
#                 "confidence": 0.57,
#                 "text": "Numarasi"
#               }
#             ]
#           },
#           {
#             "boundingBox": [
#               449,
#               219,
#               510,
#               219,
#               510,
#               230,
#               449,
#               230
#             ],
#             "text": "13211100098",
#             "words": [
#               {
#                 "boundingBox": [
#                   450,
#                   219,
#                   510,
#                   219,
#                   510,
#                   230,
#                   450,
#                   230
#                 ],
#                 "confidence": 0.909,
#                 "text": "13211100098"
#               }
#             ]
#           },
#           {
#             "boundingBox": [
#               85,
#               233,
#               426,
#               233,
#               426,
#               249,
#               85,
#               250
#             ],
#             "text": "Sozlesmenin Yururluk Tarihi / Sisteme Giris Tarihi",
#             "words": [
#               {
#                 "boundingBox": [
#                   87,
#                   234,
#                   172,
#                   234,
#                   172,
#                   250,
#                   86,
#                   250
#                 ],
#                 "confidence": 0.914,
#                 "text": "Sozlesmenin"
#               },
#               {
#                 "boundingBox": [
#                   175,
#                   234,
#                   236,
#                   233,
#                   236,
#                   250,
#                   175,
#                   250
#                 ],
#                 "confidence": 0.913,
#                 "text": "Yururluk"
#               },
#               {
#                 "boundingBox": [
#                   239,
#                   233,
#                   277,
#                   233,
#                   277,
#                   250,
#                   239,
#                   250
#                 ],
#                 "confidence": 0.852,
#                 "text": "Tarihi"
#               },
#               {
#                 "boundingBox": [
#                   281,
#                   233,
#                   288,
#                   233,
#                   288,
#                   250,
#                   281,
#                   250
#                 ],
#                 "confidence": 0.895,
#                 "text": "/"
#               },
#               {
#                 "boundingBox": [
#                   291,
#                   233,
#                   344,
#                   233,
#                   343,
#                   250,
#                   291,
#                   250
#                 ],
#                 "confidence": 0.958,
#                 "text": "Sisteme"
#               },
#               {
#                 "boundingBox": [
#                   347,
#                   233,
#                   379,
#                   233,
#                   379,
#                   250,
#                   347,
#                   250
#                 ],
#                 "confidence": 0.883,
#                 "text": "Giris"
#               },
#               {
#                 "boundingBox": [
#                   382,
#                   233,
#                   426,
#                   233,
#                   426,
#                   249,
#                   382,
#                   250
#                 ],
#                 "confidence": 0.877,
#                 "text": "Tarihi"
#               }
#             ]
#           },
#           {
#             "boundingBox": [
#               441,
#               235,
#               497,
#               235,
#               497,
#               247,
#               441,
#               247
#             ],
#             "text": ":12.12.2009",
#             "words": [
#               {
#                 "boundingBox": [
#                   443,
#                   235,
#                   497,
#                   235,
#                   497,
#                   248,
#                   443,
#                   248
#                 ],
#                 "confidence": 0.847,
#                 "text": ":12.12.2009"
#               }
#             ]
#           },
#           {
#             "boundingBox": [
#               206,
# ...
#                 "boundingBox": [
#                   90,
#                   624,
#                   122,
#                   624,
#                   122,
#                   639,
#                   90,
#                   640
#                 ],
#                 "confidence": 0.852,
#                 "text": "Giris"
#               },
#               {
#                 "boundingBox": [
#                   125,
#                   624,
#                   166,
#                   624,
#                   166,
#                   639,
#                   125,
#                   639
#                 ],
#                 "confidence": 0.687,
#                 "text": "Aidati"
#               },
#               {
#                 "boundingBox": [
#                   169,
#                   624,
#                   231,
#                   623,
#                   232,
#                   638,
#                   169,
#                   639
#                 ],
#                 "confidence": 0.958,
#                 "text": "Kesintisi"
#               }
#             ]
#           },
#           {
#             "boundingBox": [
#               504,
#               622,
#               533,
#               621,
#               533,
#               632,
#               505,
#               632
#             ],
#             "text": "91219",
#             "words": [
#               {
#                 "boundingBox": [
#                   504,
#                   621,
#                   532,
#                   621,
#                   533,
#                   632,
#                   504,
#                   632
#                 ],
#                 "confidence": 0.958,
#                 "text": "91219"
#               }
#             ]
#           },
#           {
#             "boundingBox": [
#               86,
#               640,
#               474,
#               637,
#               474,
#               654,
#               86,
#               657
#             ],
#             "text": "Aynlma Durumunda Uygulanacak Gelir Vergisi Oram /",
#             "words": [
#               {
#                 "boundingBox": [
#                   90,
#                   643,
#                   145,
#                   641,
#                   145,
#                   657,
#                   89,
#                   657
#                 ],
#                 "confidence": 0.849,
#                 "text": "Aynlma"
#               },
#               {
#                 "boundingBox": [
#                   149,
#                   641,
#                   234,
#                   639,
#                   234,
#                   657,
#                   148,
#                   657
#                 ],
#                 "confidence": 0.958,
#                 "text": "Durumunda"
#               },
#               {
#                 "boundingBox": [
#                   238,
#                   639,
#                   327,
#                   638,
#                   327,
#                   657,
#                   238,
#                   657
#                 ],
#                 "confidence": 0.957,
#                 "text": "Uygulanacak"
#               },
#               {
#                 "boundingBox": [
#                   332,
#                   638,
#                   365,
#                   638,
#                   365,
#                   656,
#                   331,
#                   657
#                 ],
#                 "confidence": 0.936,
#                 "text": "Gelir"
#               },
#               {
#                 "boundingBox": [
#                   368,
#                   638,
#                   417,
#                   637,
#                   417,
#                   656,
#                   368,
#                   656
#                 ],
#                 "confidence": 0.959,
#                 "text": "Vergisi"
#               },
#               {
#                 "boundingBox": [
#                   420,
#                   637,
#                   454,
#                   637,
#                   453,
#                   655,
#                   420,
#                   656
#                 ],
#                 "confidence": 0.57,
#                 "text": "Oram"
#               },
#               {
#                 "boundingBox": [
#                   461,
#                   637,
#                   471,
#                   637,
#                   471,
#                   655,
#                   460,
#                   655
#                 ],
#                 "confidence": 0.801,
#                 "text": "/"
#               }
#             ]
#           },
#           {
#             "boundingBox": [
#               512,
#               647,
#               547,
#               647,
#               547,
#               659,
#               512,
#               658
#             ],
#             "text": "362534",
#             "words": [
#               {
#                 "boundingBox": [
#                   513,
#                   648,
#                   548,
#                   648,
#                   548,
#                   659,
#                   513,
#                   659
#                 ],
#                 "confidence": 0.955,
#                 "text": "362534"
#               }
#             ]
#           },
#           {
#             "boundingBox": [
#               88,
#               658,
#               133,
#               658,
#               132,
#               673,
#               88,
#               673
#             ],
#             "text": "Tutan",
#             "words": [
#               {
#                 "boundingBox": [
#                   90,
#                   659,
#                   130,
#                   659,
#                   130,
#                   674,
#                   91,
#                   673
#                 ],
#                 "confidence": 0.959,
#                 "text": "Tutan"
#               }
#             ]
#           },
#           {
#             "boundingBox": [
#               91,
#               675,
#               310,
#               672,
#               310,
#               688,
#               91,
#               691
#             ],
#             "text": "AYRILMAYA ESAS NET BIRIKIM",
#             "words": [
#               {
#                 "boundingBox": [
#                   93,
#                   677,
#                   178,
#                   676,
#                   178,
#                   691,
#                   93,
#                   691
#                 ],
#                 "confidence": 0.956,
#                 "text": "AYRILMAYA"
#               },
#               {
#                 "boundingBox": [
#                   181,
#                   676,
#                   218,
#                   675,
#                   218,
#                   690,
#                   182,
#                   691
#                 ],
#                 "confidence": 0.955,
#                 "text": "ESAS"
#               },
#               {
#                 "boundingBox": [
#                   220,
#                   675,
#                   250,
#                   674,
#                   250,
#                   690,
#                   221,
#                   690
#                 ],
#                 "confidence": 0.949,
#                 "text": "NET"
#               },
#               {
#                 "boundingBox": [
#                   253,
#                   674,
#                   304,
#                   673,
#                   304,
#                   689,
#                   253,
#                   690
#                 ],
#                 "confidence": 0.727,
#                 "text": "BIRIKIM"
#               }
#             ]
#           },
#           {
#             "boundingBox": [
#               513,
#               676,
#               548,
#               675,
#               548,
#               686,
#               513,
#               687
#             ],
#             "text": "362534",
#             "words": [
#               {
#                 "boundingBox": [
#                   513,
#                   676,
#                   549,
#                   676,
#                   549,
#                   687,
#                   513,
#                   687
#                 ],
#                 "confidence": 0.931,
#                 "text": "362534"
#               }
#             ]
#           },
#           {
#             "boundingBox": [
#               56,
#               975,
#               583,
#               971,
#               583,
#               983,
#               56,
#               987
#             ],
#             "text": "Dead Linesa: Anadole Hayat Emekbank A $. Dicaret Sicil Sumaras: 265737 Sicket Merkeck ly Kuleler Kule: 2 Kat:16-20 34330 Levent Bepiktag Istanbul",
#             "words": [
#               {
#                 "boundingBox": [
#                   57,
#                   975,
#                   76,
#                   975,
#                   76,
#                   986,
#                   57,
#                   986
#                 ],
#                 "confidence": 0.429,
#                 "text": "Dead"
#               },
#               {
#                 "boundingBox": [
#                   79,
#                   975,
#                   104,
#                   975,
#                   104,
#                   986,
#                   79,
#                   986
#                 ],
#                 "confidence": 0.252,
#                 "text": "Linesa:"
#               },
#               {
#                 "boundingBox": [
#                   106,
#                   975,
#                   135,
#                   975,
#                   135,
#                   986,
#                   106,
#                   986
#                 ],
#                 "confidence": 0.397,
#                 "text": "Anadole"
#               },
#               {
#                 "boundingBox": [
#                   137,
#                   975,
#                   158,
#                   975,
#                   158,
#                   986,
#                   137,
#                   986
#                 ],
#                 "confidence": 0.624,
#                 "text": "Hayat"
#               },
#               {
#                 "boundingBox": [
#                   160,
#                   975,
#                   193,
#                   975,
#                   193,
#                   986,
#                   160,
#                   986
#                 ],
#                 "confidence": 0.276,
#                 "text": "Emekbank"
#               },
#               {
#                 "boundingBox": [
#                   195,
#                   975,
#                   201,
#                   975,
#                   201,
#                   986,
#                   195,
#                   986
#                 ],
#                 "confidence": 0.84,
#                 "text": "A"
#               },
#               {
#                 "boundingBox": [
#                   203,
#                   975,
#                   213,
#                   975,
#                   213,
#                   986,
#                   203,
#                   986
#                 ],
#                 "confidence": 0.434,
#                 "text": "$."
#               },
#               {
#                 "boundingBox": [
#                   215,
#                   975,
#                   240,
#                   975,
#                   240,
#                   986,
#                   215,
#                   986
#                 ],
#                 "confidence": 0.57,
#                 "text": "Dicaret"
#               },
#               {
#                 "boundingBox": [
#                   242,
#                   975,
#                   257,
#                   975,
#                   257,
#                   986,
#                   242,
#                   986
#                 ],
#                 "confidence": 0.57,
#                 "text": "Sicil"
#               },
#               {
#                 "boundingBox": [
#                   259,
#                   975,
#                   295,
#                   974,
#                   295,
#                   986,
#                   259,
#                   986
#                 ],
#                 "confidence": 0.279,
#                 "text": "Sumaras:"
#               },
#               {
#                 "boundingBox": [
#                   297,
#                   974,
#                   322,
#                   974,
#                   321,
#                   985,
#                   297,
#                   986
#                 ],
#                 "confidence": 0.812,
#                 "text": "265737"
#               },
#               {
#                 "boundingBox": [
#                   324,
#                   974,
#                   343,
#                   974,
#                   343,
#                   985,
#                   324,
#                   985
#                 ],
#                 "confidence": 0.436,
#                 "text": "Sicket"
#               },
#               {
#                 "boundingBox": [
#                   345,
#                   974,
#                   375,
#                   974,
#                   375,
#                   985,
#                   345,
#                   985
#                 ],
#                 "confidence": 0.292,
#                 "text": "Merkeck"
#               },
#               {
#                 "boundingBox": [
#                   377,
#                   974,
#                   383,
#                   974,
#                   383,
#                   985,
#                   377,
#                   985
#                 ],
#                 "confidence": 0.308,
#                 "text": "ly"
#               },
#               {
#                 "boundingBox": [
#                   385,
#                   974,
#                   412,
#                   973,
#                   412,
#                   985,
#                   385,
#                   985
#                 ],
#                 "confidence": 0.441,
#                 "text": "Kuleler"
#               },
#               {
#                 "boundingBox": [
#                   414,
#                   973,
#                   432,
#                   973,
#                   432,
#                   984,
#                   414,
#                   985
#                 ],
#                 "confidence": 0.694,
#                 "text": "Kule:"
#               },
#               {
#                 "boundingBox": [
#                   434,
#                   973,
#                   438,
#                   973,
#                   438,
#                   984,
#                   434,
#                   984
#                 ],
#                 "confidence": 0.888,
#                 "text": "2"
#               },
#               {
#                 "boundingBox": [
#                   440,
#                   973,
#                   473,
#                   973,
#                   473,
#                   984,
#                   440,
#                   984
#                 ],
#                 "confidence": 0.428,
#                 "text": "Kat:16-20"
#               },
#               {
#                 "boundingBox": [
#                   475,
#                   973,
#                   495,
#                   973,
#                   495,
#                   984,
#                   475,
#                   984
#                 ],
#                 "confidence": 0.849,
#                 "text": "34330"
#               },
#               {
#                 "boundingBox": [
#                   497,
#                   973,
#                   520,
#                   972,
#                   520,
#                   983,
#                   497,
#                   984
#                 ],
#                 "confidence": 0.947,
#                 "text": "Levent"
#               },
#               {
#                 "boundingBox": [
#                   523,
#                   972,
#                   551,
#                   972,
#                   551,
#                   983,
#                   522,
#                   983
#                 ],
#                 "confidence": 0.289,
#                 "text": "Bepiktag"
#               },
#               {
#                 "boundingBox": [
#                   553,
#                   972,
#                   584,
#                   971,
#                   584,
#                   982,
#                   553,
#                   983
#                 ],
#                 "confidence": 0.547,
#                 "text": "Istanbul"
#               }
#             ]
#           }
#         ],
#         "page": 1,
#         "unit": "pixel",
#         "width": 762
#       }
#     ],
#     "version": "2.0.0"
#   },
#   "createdDateTime": "2021-02-23T12:26:33Z",
#   "lastUpdatedDateTime": "2021-02-23T12:26:39Z",
#   "status": "succeeded"
# }
# Analyze operation did not complete within the allocated time.
